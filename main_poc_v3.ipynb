# %%
from poc_data_v2 import generate_sample, display_sample
import matplotlib.pyplot as plt
import numpy as np

a = generate_sample()
display_sample(a)
print(a[2])
print(a[0])
# Out:
# Event is 2, Length is 35
# (25, 9)
# tensor([[ 0.0000e+00,  3.5000e+01,  3.4000e+01,  1.9925e-01,  5.4098e-01],
#         [ 1.0000e+00,  3.5000e+01,  3.3000e+01,  4.5109e-01, -4.1315e-01],
#         [ 2.0000e+00,  3.5000e+01,  3.2000e+01,  2.8819e-01, -9.8743e-01],
#         [ 3.0000e+00,  3.5000e+01,  3.1000e+01, -1.3966e-01, -6.5387e-01],
#         [ 4.0000e+00,  3.5000e+01,  3.0000e+01, -4.3912e-01,  2.8085e-01],
#         [ 5.0000e+00,  3.5000e+01,  2.9000e+01, -3.3485e-01,  9.5736e-01],
#         [ 6.0000e+00,  3.5000e+01,  2.8000e+01,  7.7280e-02,  7.5368e-01],
#         [ 7.0000e+00,  3.5000e+01,  2.7000e+01,  4.1835e-01, -1.4293e-01],
#         [ 8.0000e+00,  3.5000e+01,  2.6000e+01,  3.7480e-01, -9.0813e-01],
#         [ 9.0000e+00,  3.5000e+01,  2.5000e+01, -1.3348e-02, -8.3840e-01],
#         [ 1.0000e+01,  3.5000e+01,  2.4000e+01, -3.8922e-01,  2.1539e-03],
#         [ 1.1000e+01,  3.5000e+01,  2.3000e+01, -4.0724e-01,  8.4073e-01],
# ...

# %%
for i in range(5000):
    a = generate_sample()
    if a[0].shape[0] =< 2:
        print(a[0])

# %%
print(min(l))
# Out:
# 2
